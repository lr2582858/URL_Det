# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('chislab.json',orient="split")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157110 entries, 0 to 157109
# Data columns (total 17 columns):
# Accept             157110 non-null object
# Accept-Charset     157110 non-null object
# Accept-Encoding    157110 non-null object
# Accept-Language    157110 non-null object
# Cache-control      157110 non-null object
# Connection         157110 non-null object
# Content-Length     157110 non-null int64
# Content-Type       157110 non-null object
# Cookie             157110 non-null object
# Host               157110 non-null object
# Pragma             157110 non-null object
# User-Agent         157110 non-null object
# X-Real-IP          157110 non-null object
# argument           157110 non-null object
# http               157110 non-null object
# method             157110 non-null object
# url                157110 non-null object
# dtypes: int64(1), object(16)
# memory usage: 20.4+ MB

# %%
data.head(3)
# Out:
#                                             Accept Accept-Charset  \
# 0                                              */*
# 1                                              */*
# 2   application/json, text/javascript, */*; q=0.01
#
#       Accept-Encoding                                    Accept-Language  \
# 0   gzip, deflate, br   en-US,en;q=0.9,en-GB;q=0.8,zh-CN;q=0.7,zh;q=0...
# 1   gzip, deflate, br   en-US,en;q=0.9,en-GB;q=0.8,zh-CN;q=0.7,zh;q=0...
# 2   gzip, deflate, br   en-US,en;q=0.9,en-GB;q=0.8,zh-CN;q=0.7,zh;q=0...
#
#   Cache-control Connection  Content-Length  \
# 0                    close             164
# 1                    close             135
# 2                    close             159
#
#                                         Content-Type  \
# 0
# 1
# 2   application/x-www-form-urlencoded; charset=UTF-8
#
#                                               Cookie               Host  \
# 0   mywork.tab.tasks=false; confluence.browse.spa...   wiki.chislab.com
# ...

# %%
a = data.nunique()
a.sort_values(ascending=False)
# Out:
# url                1819
# Content-Length     1792
# Cookie              622
# X-Real-IP            98
# User-Agent           85
# Accept               30
# Accept-Language      22
# Accept-Encoding      12
# Content-Type         10
# Pragma                2
# method                2
# argument              1
# Host                  1
# http                  1
# Connection            1
# Cache-control         1
# Accept-Charset        1
# dtype: int64

# %%
url_uniq = pd.DataFrame()
url_uniq['Url'] = data["url"].unique()
#print(url_uniq)
url_uniq.to_csv('url.csv')

# %%
data.corr()
# Out:
#                 Content-Length
# Content-Length             1.0

# %%
a = data['url'].drop_duplicates()
url = pd.DataFrame()
url['url'] = a.values

b = url.url
url_sp = b.str.split('/',expand=True).drop(columns=0)
print(url_sp.shape)
url_sp
# Out:
# (1819, 15)
#                              1                                        2   \
# 0               synchrony-proxy                                       v1
# 1                          json            startheartbeatactivity.action
# 2                          rest                                analytics
# 3                        Attach            page-icon(11-13-13-23-05).png
# 4                        Attach     footer-desktop-l(11-13-13-23-05).png
# 5                        Attach     footer-mobile-lo(11-13-13-23-05).png
# 6                        Attach     avatar_80747d194(11-13-13-23-05).png
# 7                        Attach     footer-mobile-lo(11-13-13-57-49).png
# 8                        Attach     avatar_60f0e4909(11-13-13-57-49).jpg
# 9                        Attach        blogpost-icon(11-13-13-57-49).png
# 10                       Attach     footer-desktop-l(11-13-13-57-49).png
# 11                         rest                              quickreload
# ...

# %%
b = url_sp.iloc[:,0]=="Attach"
b.sum()
# Out:
# 344

# %%
url_sp.iloc[:,0].unique()
# Out:
# array(['synchrony-proxy', 'json', 'rest', 'Attach', 'pages', 'download',
#        'attachmentnotfound.action', 'plugins', 'synchrony', 's', 'images',
#        'users', 'login.action', 'index.action', '', 'opensearch',
#        'browsepeople.action', 'display', 'collector', 'dologin.action',
#        'robots.txt', 'calendar', 'spacedirectory', 'favicon.ico',
#        '#all-updates', 'dosearchsite.action', 'dashboard',
#        'apple-touch-icon-precomposed.png', 'apple-touch-icon.png',
#        'welcome.action', 'dashboard.action', 'spaces',
#        'dopeopledirectorysearch.action', 'authenticate.action',
#        'doauthenticate.action', 'logout.action', 'admin', 'labels'],
#       dtype=object)

# %%
url_sp
# Out:
#                              1                                        2   \
# 0               synchrony-proxy                                       v1
# 1                          json            startheartbeatactivity.action
# 2                          rest                                analytics
# 3                        Attach            page-icon(11-13-13-23-05).png
# 4                        Attach     footer-desktop-l(11-13-13-23-05).png
# 5                        Attach     footer-mobile-lo(11-13-13-23-05).png
# 6                        Attach     avatar_80747d194(11-13-13-23-05).png
# 7                        Attach     footer-mobile-lo(11-13-13-57-49).png
# 8                        Attach     avatar_60f0e4909(11-13-13-57-49).jpg
# 9                        Attach        blogpost-icon(11-13-13-57-49).png
# 10                       Attach     footer-desktop-l(11-13-13-57-49).png
# 11                         rest                              quickreload
# ...
